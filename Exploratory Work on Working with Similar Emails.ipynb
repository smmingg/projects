# %%
import pandas as pd
import numpy as np
import numpy as np
from scipy.sparse import csr_matrix
import sparse_dot_topn.sparse_dot_topn as ct
from tqdm import tqdm_notebook as tqdm
import re

from multiprocessing import Pool
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-95b3dcf22b92> in <module>
#       3 import numpy as np
#       4 from scipy.sparse import csr_matrix
# ----> 5 import sparse_dot_topn.sparse_dot_topn as ct
#       6 from tqdm import tqdm_notebook as tqdm
#       7 import re
#
# ModuleNotFoundError: No module named 'sparse_dot_topn'

# %%
df = pd.read_csv("export_rws_jultooct18_v3.csv")

# %%
len(np.unique(df['data.user_email'].str.lower()).tolist())
# Out:
# 69616

# %% [markdown]
# # Idea 1: TFIDF with N grams

# %% [markdown]
# Advantages: 1. Scalable, fast, can be distributed using Spark

# %% [markdown]
# Disadvantages: How accurate the results are? Are there a lot of false positives?

# %%
def ngrams(string, n=3):
    """
     
    Get the n-grams of the strings with some cleaning such as removing punctuations like ,_./ or \sBD.
    """
    string = re.sub(r'[,-./]|\sBD',r'', string)
    ngrams = zip(*[string[i:] for i in range(n)])
    return [''.join(ngram) for ngram in ngrams]

# %%
#The code below generate tf-idf for each email in email_names
from sklearn.feature_extraction.text import TfidfVectorizer

email_names = np.unique(df['data.user_email'].str.lower()).tolist()[:10000]
vectorizer = TfidfVectorizer(min_df=1, analyzer=ngrams)
tf_idf_matrix = vectorizer.fit_transform(email_names)

# %%
tf_idf_matrix.shape
# Out:
# (10000, 14938)

# %%
def awesome_cossim_top(A, B, ntop, lower_bound=0):
    """
    Given two csr sparse matrices, we calculate the cosine similarity between the two matrices.
    In our case, we calculate the cosine similarity of the tfidf representation of each email addresses in our list.
    We are using sparse_dot_topn algorithm in performing sparse matrix multiplication followed by topn multiplication
    result selection. This algorithm is customized cython function of comparing large tfidf feature vectors and picking
    up the best matches using cosine similarity measure.
    """
    A = A.tocsr()
    B = B.tocsr()
    M, _ = A.shape
    _, N = B.shape
 
    idx_dtype = np.int32
 
    nnz_max = M*ntop
 
    indptr = np.zeros(M+1, dtype=idx_dtype)
    indices = np.zeros(nnz_max, dtype=idx_dtype)
    data = np.zeros(nnz_max, dtype=A.dtype)

    ct.sparse_dot_topn(
        M, N, np.asarray(A.indptr, dtype=idx_dtype),
        np.asarray(A.indices, dtype=idx_dtype),
        A.data,
        np.asarray(B.indptr, dtype=idx_dtype),
        np.asarray(B.indices, dtype=idx_dtype),
        B.data,
        ntop,
        lower_bound,
        indptr, indices, data)

    return csr_matrix((data,indices,indptr),shape=(M,N))

# %%
# %%time

#We are getting the top 100 matches of each email with a similarity measure greater than or equal to 0.5.
matches = awesome_cossim_top(tf_idf_matrix, tf_idf_matrix.transpose(), 100, 0.5)
# Out:
# CPU times: user 965 ms, sys: 6.53 ms, total: 971 ms
# Wall time: 1 s

# %%
def get_matches_df(sparse_matrix, name_vector, top=100):
    """
    Unpack the resulting sparse matrix. We set an option to look into the first n values of the matches matrix.
    
    """
    non_zeros = sparse_matrix.nonzero()
    
    sparserows = non_zeros[0]
    sparsecols = non_zeros[1]
    
    if top:
        nr_matches = top
    else:
        nr_matches = sparsecols.size
    
    left_side = np.empty([nr_matches], dtype=object)
    right_side = np.empty([nr_matches], dtype=object)
    similarity = np.zeros(nr_matches)
    
    for index in range(0, nr_matches):
        left_side[index] = name_vector[sparserows[index]]
        right_side[index] = name_vector[sparsecols[index]]
        similarity[index] = sparse_matrix.data[index]
    
    return pd.DataFrame({'left_side': left_side,
                          'right_side': right_side,
                           'similarity': similarity})

# %%
matches_df = get_matches_df(matches, user_emails, top=11468)
matches_df = matches_df[(matches_df['similarity'] > 0.5) & (matches_df['similarity'] <= 0.99999)] # Remove all exact matches
matches_df.sort_values(by=['similarity'], ascending=0)
# Out:
#                          left_side                   right_side  similarity
# 1754   afiqahahmadmazlan@gmail.com   afiqahahmadmazlan@gmail.co    0.999201
# 1750    afiqahahmadmazlan@gmail.co  afiqahahmadmazlan@gmail.com    0.999201
# 3044    alicecranberry23@gmail.com   alicecranberry23@gmail.con    0.976109
# 3046    alicecranberry23@gmail.con   alicecranberry23@gmail.com    0.976109
# 6702         askoddsynow@gmail.com        askoddsynow@gmail.con    0.975656
# 6704         askoddsynow@gmail.con        askoddsynow@gmail.com    0.975656
# 2669       albertlam0912@gmail.com      albertlam0912@gmail.con    0.974450
# 2671       albertlam0912@gmail.con      albertlam0912@gmail.com    0.974450
# 4503    andresin.zsanett@gmail.con   andresin.zsanett@gmail.com    0.972773
# 4501    andresin.zsanett@gmail.com   andresin.zsanett@gmail.con    0.972773
# 10887   catherinetanlg@hotmail.com   catherinetanlg@hotmail.con    0.969375
# 10890   catherinetanlg@hotmail.con   catherinetanlg@hotmail.com    0.969375
# 1477       admin@hipstercity.rocks       admin@hipstercity.rock    0.969130
# 1474        admin@hipstercity.rock      admin@hipstercity.rocks    0.969130
# 8403          benseehx@hotmail.com         benseehx@hotmail.con    0.966692
# 8405          benseehx@hotmail.con         benseehx@hotmail.com    0.966692
# 2323          ajaaan1998@gmail.con         ajaaan1998@gmail.com    0.965210
# 2321          ajaaan1998@gmail.com         ajaaan1998@gmail.con    0.965210
# 6234            arnav04g@gmail.con           arnav04g@gmail.com    0.964566
# 6232            arnav04g@gmail.com           arnav04g@gmail.con    0.964566
# 3605         alvisstok@hotmail.con        alvisstok@hotmail.com    0.963387
# 3603         alvisstok@hotmail.com        alvisstok@hotmail.con    0.963387
# 3627             alwyn.kv@live.com            alwyn.kv@live.col    0.961429
# 3625             alwyn.kv@live.col            alwyn.kv@live.com    0.961429
# 1189        adamfaris099@gmail.com      adamfaris0999@gmail.com    0.958444
# 1187       adamfaris0999@gmail.com       adamfaris099@gmail.com    0.958444
# 2233           airie89@hotmail.com          airie89@hotmail.con    0.954100
# 2235           airie89@hotmail.con          airie89@hotmail.com    0.954100
# 704         aaron.cheong@gmail.com         aroncheong@gmail.com    0.951113
# 6260          aroncheong@gmail.com       aaron.cheong@gmail.com    0.951113
# ...                            ...                          ...         ...
# 10843   catherine.ting@outlook.com         billwong@outlook.com    0.501075
# 8816          billwong@outlook.com   catherine.ting@outlook.com    0.501075
# 3379       aloysius88tan@gmail.com        aloysiusmun@gmail.com    0.500934
# 3397         aloysiusmun@gmail.com      aloysius88tan@gmail.com    0.500934
# 8654           bharadian@gmail.com          adianadian@live.com    0.500925
# 1379           adianadian@live.com          bharadian@gmail.com    0.500925
# 5426         anneka@singnet.com.sg     aileenwal@singnet.com.sg    0.500870
# 2125      aileenwal@singnet.com.sg        anneka@singnet.com.sg    0.500870
# 10127        cahs49@googlemail.com  ammar.maslan@googlemail.com    0.500713
# 4116   ammar.maslan@googlemail.com        cahs49@googlemail.com    0.500713
# 4638        andrtyl@btinternet.com       anthjtb@btinternet.com    0.500659
# 5606        anthjtb@btinternet.com       andrtyl@btinternet.com    0.500659
# 1044             acapri@nus.edu.sg           ceeliyy@nus.edu.sg    0.500627
# 11115           ceeliyy@nus.edu.sg            acapri@nus.edu.sg    0.500627
# 5692         antsaw@singnet.com.sg       angeric@singnet.com.sg    0.500483
# 5031        angeric@singnet.com.sg        antsaw@singnet.com.sg    0.500483
# 598             a14106@hanmail.net          9731065@hanmail.net    0.500451
# 490            9731065@hanmail.net           a14106@hanmail.net    0.500451
# 4908     angeliajingjing@gmail.com      changjing93@hotmail.com    0.500387
# 11446      changjing93@hotmail.com    angeliajingjing@gmail.com    0.500387
# 8294    benjamin.halter@bluewin.ch            calinc@bluewin.ch    0.500369
# 10192            calinc@bluewin.ch   benjamin.halter@bluewin.ch    0.500369
# 2244            airingel@yahoo.com       airing.arias@yahoo.com    0.500285
# 2242        airing.arias@yahoo.com           airingel@yahoo.com    0.500285
# 5796            apanna@hotmail.com      biancapanda@hotmail.com    0.500147
# 8725       biancapanda@hotmail.com           apanna@hotmail.com    0.500147
# 8849           binchew@outlook.com         ben.chia@outlook.com    0.500084
# 8194          ben.chia@outlook.com          binchew@outlook.com    0.500084
# 2784         alex.ngkang@gmail.com          alex.ng78@gmail.com    0.500003
# 2781           alex.ng78@gmail.com        alex.ngkang@gmail.com    0.500003
#
# [1444 rows x 3 columns]

# %%
matches_df[matches_df['left_side'] == 'carenlou0810@gmail.com']
# Out:
#                     left_side          right_side  similarity
# 10436  carenlou0810@gmail.com  carenlou@gmail.com     0.52716

# %% [markdown]
# # Idea 2: Use Voldemort FuzzyWuzzy Idea

# %%
import re
from collections import Counter
from fuzzywuzzy import fuzz, process
# Out:
# /Users/algerremirata/miniconda3/envs/data_integration/lib/python3.4/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
def match_score(a, b):
    confUnRaw = fuzz.ratio(a[0], b[0])
    confUn = fuzz.ratio(a[1], b[1])
    conf = fuzz.ratio(a[3], b[3])
    return (confUnRaw + confUn * 2 + conf) / 4


def match_process(s):
    s = s.split("@", 1)
    if len(s) < 2:
        s.insert(1, "")
    cleaned_username = re.sub(r"[\d\W]", "", s[0])
    s.insert(1, cleaned_username)
    clean_full = "@".join(s[1:3])
    s.append(clean_full)
    # s.append(orig)
    # 0 raw username, 1 clean username, 2 domain (blank if doesn't exist), 3 clean full#, 4 raw full
    return s

# %%
def similar_email_vold(user_email, user_emails):
    user_emails = Counter(user_emails)
    user_email_list = [i for i in user_emails]
    matches = process.extractBests(user_email, user_email_list, processor=match_process, scorer=match_score, score_cutoff=85, limit=20)
    scores = []
    sum_score = 0
    for match, confidence in matches:
        numTx = user_emails[match]
        if match != user_email:
            scores.append(numTx * 10)
    if scores:
        sum_score = min([sum(scores), 50])
        # if isEmoto(transaction):
        # 	this.addReason("\n<br>Extra emoto score", sum_score)
    return sum_score

# %% [markdown]
# Using a unique or not in the list of emails to worked on.

# %%
# %%time

user_emails = df['data.user_email'].tolist()[:1000]
user_emails = [email.lower() for email in list(set(user_emails))]

df4 = pd.DataFrame({'emails': list(user_emails)})
df4['score'] = 0
for idx, address in enumerate(tqdm(user_emails)):
    score = similar_email_vold(address, user_emails)
    df4.loc[idx, 'score'] = score
# Out:
# CPU times: user 4h 36min 54s, sys: 39.6 s, total: 4h 37min 34s
# Wall time: 7h 11min 22s

# %% [markdown]
# # Optimizing Voldemort Fuzzy Wuzzy Method

# %%
def similar_email_vold(user_email, user_emails):
    user_emails = Counter(user_emails)
    user_email_list = [i for i in user_emails]
    matches = process.extractBests(user_email, user_email_list, processor=match_process, scorer=match_score, score_cutoff=85, limit=20)
    scores = []
    sum_score = 0
    for match, confidence in matches:
        numTx = user_emails[match]
        if match != user_email:
            scores.append(numTx * 10)
    if scores:
        sum_score = min([sum(scores), 50])
        # if isEmoto(transaction):
        # this.addReason("\n<br>Extra emoto score", sum_score)
    return sum_score

# %%
# %%time

user_emails = df['data.user_email'].tolist()[:1000]
user_emails = [email.lower() for email in list(set(user_emails))]

df4 = pd.DataFrame({'emails': list(user_emails)})
df4['score'] = 0
for idx, address in enumerate(tqdm(user_emails)):
    score = similar_email_vold(address, user_emails)
    df4.loc[idx, 'score'] = score
# Out:
# CPU times: user 1min 50s, sys: 893 ms, total: 1min 51s
# Wall time: 1min 51s

# %%
df4.sort_values(by=['score'], ascending=0)
# Out:
#                             emails  score
# 584             carenlou@gmail.com     20
# 495         tanya.andrew@gmail.com     20
# 551        chan_carisssa@yahoo.com     10
# 783      riyahkusniawati@gmail.com     10
# 517         carenlou0810@gmail.com     10
# 189                 j-oyy@live.com     10
# 832              1114572634@qq.com     10
# 791           west2711@hotmail.com     10
# 793  www.riyahkusniawati@gmail.com     10
# 511         chan_carissa@yahoo.com     10
# 251          dianasinona@yahoo.com     10
# 75           dianasinona@gmail.com     10
# 603          west2711@hotmail.comm     10
# 71        yohanesjeffryj@gmail.com     10
# 811                 j-oyy@live.xom     10
# 61          tanyl.andrew@gmail.com     10
# 197          airina_86@hotmail.com     10
# 64          tanyl.andrew@gmail.com     10
# 221         carenlou0810@gmail.com     10
# 751      yohanesjeffryj@icloud.com     10
# 1          airina_ng86@hotmail.com     10
# 589             nicsimch@gmail.com      0
# 583         helenthm2008@gmail.com      0
# 556           t.elainecd@gmail.com      0
# 585          justinlim88@yahoo.com      0
# 555             postics2@gmail.com      0
# 586            eclee2015@gmail.com      0
# 587       farshahilzshah@gmail.com      0
# 554         ong_wei_han@moe.edu.sg      0
# 588         heli20092010@gmail.com      0
# ..                             ...    ...
# 326     andy.remy.garcia@gmail.com      0
# 327         weilin.kalyn@gmail.com      0
# 328     amira.raihanah@outlook.com      0
# 305             burragah@gmail.com      0
# 304           wendyk11@hotmail.com      0
# 303           ballonelay@gmail.com      0
# 290          tanjonkyley@gmail.com      0
# 280       v.i.figuracion@gmail.com      0
# 281          bae.lalitha@gmail.com      0
# 282         buwenliang04@gmail.com      0
# 283        kwek_sally@yahoo.com.sg      0
# 284   julianne.stewart17@gmail.com      0
# 285           nurdinna97@gmail.com      0
# 286              ssts_00@yahoo.com      0
# 287     nathalie.legree@hotmail.fr      0
# 288            quahtw@yahoo.com.sg      0
# 289   joshuaimmortals383@gmail.com      0
# 291               243352975@qq.com      0
# 302        olga_kolmykova@inbox.ru      0
# 292                  sothy@mac.com      0
# 293           sivadta@yahoo.com.sg      0
# 294    amirulhikmah_95@outlook.com      0
# 295       chandrakar.jha@gmail.com      0
# 296           jovanleegh@gmail.com      0
# 297      joallinejessica@gmail.com      0
# 298          iwanjuniorr@gmail.com      0
# 299        leechristabel@gmail.com      0
# 300             yudopria@gmail.com      0
# 301        livviemilne62@gmail.com      0
# 870          isis.alle@hotmail.com      0
#
# [871 rows x 2 columns]

# %% [markdown]
# # Idea 3: Use Jellyfish Algorithms for Distances

# %%
import jellyfish

# %%
email_names = np.unique(df['data.user_email'].str.lower()).tolist()[:10000]

# %%
def get_jellyfish_similarity(email_names, name, top_n, algo='jellyfish.jaro_distance', reverse=True):
    """
    Compute similarity between two email addresses using the define distance measure and display top_n most similar
    email addresses together with its score
    
    email_names: list of all email_addresses to be scanned for similarity
    name: an email_add to be used as basis for searching most similar email address
    top_n: n most similar email addresses to display
    algo: jellyfish algorithm to be used for examining similarity
    reverse: identifier if reverse is used in sorting; this depends on the similarity measure used
    """
    
    top_n = sorted(list(map(lambda x: ((x, name),
            eval(algo)(x, name)), email_names)), key= lambda x: x[1], reverse=reverse)[:top_n]
    
    return list(filter(lambda x: x[1] > 0, top_n))

# %%
def get_similarity_matrix(email_names, top_n, algo, reverse):
    
    df = []
    
    for email in tqdm(email_names):
        sim_email = get_jellyfish_similarity(email_names, email, top_n, algo, reverse)
        sim_df = pd.DataFrame(sim_email, columns=['email_names','similarity_score'])
        sim_df[['email_1', 'email_2']] = sim_df['email_names'].apply(pd.Series)
        sim_df = sim_df.drop('email_names', axis=1)
        df.append(sim_df)
        
    return pd.concat(df, ignore_index=True)

# %% [markdown]
# ### JARO DISTANCE

# %%
# %%time

sim_jaro = get_similarity_matrix(email_names, 10, algo='jellyfish.jaro_distance', reverse=True)
# Out:
# CPU times: user 18min 34s, sys: 11.2 s, total: 18min 45s
# Wall time: 19min 4s

# %%
sim_jaro = sim_jaro.sort_values(by=['similarity_score'], ascending=False)

# %%
sim_jaro[sim_jaro['email_1'].str.contains('carenlou@gmail.com')]
# Out:
#        similarity_score             email_1                  email_2
# 91180          1.000000  carenlou@gmail.com       carenlou@gmail.com
# 91171          0.939394  carenlou@gmail.com   carenlou0810@gmail.com
# 90294          0.905093  carenlou@gmail.com       candolee@gmail.com
# 60263          0.901688  carenlou@gmail.com        auclove@gmail.com
# 72951          0.892266  carenlou@gmail.com     benlacount@gmail.com
# 28717          0.889498  carenlou@gmail.com      allencjho@gmail.com
# 83072          0.888889  carenlou@gmail.com       breloque@gmail.com
# 58524          0.888889  carenlou@gmail.com       asrielko@gmail.com
# 88171          0.888889  carenlou@gmail.com       caceyloh@gmail.com
# 93334          0.878307  carenlou@gmail.com    carolyuenaz@gmail.com
# 91941          0.875463  carenlou@gmail.com     carluqpe92@gmail.com
# 90434          0.875463  carenlou@gmail.com     candyherox@gmail.com
# 99316          0.875463  carenlou@gmail.com     chanceleow@gmail.com
# 91133          0.874269  carenlou@gmail.com      caren1310@gmail.com
# 91695          0.874269  carenlou@gmail.com      carlo1108@gmail.com
# 86651          0.871981  carenlou@gmail.com  burleenahchoy@gmail.com
# 91925          0.862765  carenlou@gmail.com    carlton1509@gmail.com
# 55333          0.855309  carenlou@gmail.com  arunjudelopez@gmail.com
# 78368          0.854630  carenlou@gmail.com     blackurses@gmail.com
# 96146          0.851852  carenlou@gmail.com       ccstanlk@gmail.com
# 14768          0.851221  carenlou@gmail.com   aeonzephyrus@gmail.com
# 74057          0.851221  carenlou@gmail.com   bernardlowyr@gmail.com
# 52738          0.849206  carenlou@gmail.com    arielquek27@gmail.com
# 55142          0.836640  carenlou@gmail.com         arun@olamnet.com
# 72967          0.827293  carenlou@gmail.com   benleau@rocketmail.com
# 97705          0.821549  carenlou@gmail.com              ceno@me.com
# 2759           0.806280  carenlou@gmail.com  36.terencelee@gmail.com
# 97745          0.702381  carenlou@gmail.com           ceo@aib.org.au

# %% [markdown]
# # Idea 4: Using Sequence Matcher

# %%
def get_sequencematcher_similarity(email_names, name, threshold, reverse=True):
    """
    Compute similarity between two email addresses using the define distance measure and display top_n most similar
    email addresses together with its score
    
    email_names: list of all email_addresses to be scanned for similarity
    name: an email_add to be used as basis for searching most similar email address
    top_n: n most similar email addresses to display
    algo: jellyfish algorithm to be used for examining similarity
    reverse: identifier if reverse is used in sorting; this depends on the similarity measure used
    """
    
    sort_sim = sorted(list(map(lambda x: ((x, name),SequenceMatcher(None,x,name).ratio()), email_names)), reverse=True)
    
    return list(filter(lambda x: x[1] > threshold, sort_sim))

# %%
def get_similarity_sequencematcher(email_names, threshold, reverse):
    
    df = []
    
    for email in tqdm(email_names):
        sim_email = get_sequencematcher_similarity(email_names, email, threshold, reverse)
        sim_df = pd.DataFrame(sim_email, columns=['email_names','similarity_score'])
        sim_df[['email_1', 'email_2']] = sim_df['email_names'].apply(pd.Series)
        sim_df = sim_df.drop('email_names', axis=1)
        df.append(sim_df)
        
    return pd.concat(df, ignore_index=True)

# %%
get_similarity_sequencematcher(email_names, 0.85, True)
# Out:
#        similarity_score                             email_1  \
# 0              1.000000                000grace@hanmail.net
# 1              1.000000                00116082@sats.com.sg
# 2              1.000000                00248024@sats.com.sg
# 3              1.000000                 007banggu@naver.com
# 4              0.857143                  77eileen@gmail.com
# 5              1.000000                   007elee@gmail.com
# 6              1.000000            00wjddmswn00@hanmail.net
# 7              0.857143                   4baobei@gmail.com
# 8              1.000000                  0104babi@gmail.com
# 9              1.000000                 0106vchng@gmail.com
# 10             0.882353                    4wlswn@naver.com
# 11             1.000000                  010wlswn@naver.com
# 12             1.000000                  0113sota@gmail.com
# 13             1.000000                0116149694@naver.com
# 14             1.000000               01192876615@naver.com
# 15             1.000000                01410ppcom@naver.com
# 16             1.000000  01533.concierge@starwoodhotels.com
# 17             1.000000               01692310506@naver.com
# 18             1.000000              0202basket@hanmail.net
# 19             1.000000                 02qowlsdn@gmail.com
# 20             1.000000                   0305njd@gmail.com
# 21             1.000000                0306isabel@gmail.com
# 22             1.000000                  0316jina@naver.com
# 23             1.000000               0322shunlai@gmail.com
# 24             1.000000                   0328hsh@naver.com
# 25             1.000000                 0442hours@gmail.com
# 26             1.000000             0508tonhyuk@hanmail.net
# 27             1.000000                  0516hsun@gmail.com
# 28             1.000000                06chandarm@aisgz.org
# 29             1.000000            06chinyichyuan@gmail.com
# ...                 ...                                 ...
# 14048          1.000000             changmanhoong@gmail.com
# 14049          0.863636               angyanghoon@gmail.com
# 14050          0.918919                 changqj89@gmail.com
# 14051          1.000000                  changq88@gmail.com
# 14052          0.857143                   changbp@gmail.com
# 14053          0.882353                    angh88@gmail.com
# 14054          1.000000                 changqj89@gmail.com
# 14055          0.918919                  changq88@gmail.com
# 14056          0.864865                  chanby89@gmail.com
# 14057          1.000000                 changrs95@gmail.com
# 14058          1.000000               changsheng@live.co.uk
# 14059          1.000000          changtsejung0411@gmail.com
# 14060          1.000000       changxi@thegoldenconcepts.com
# 14061          1.000000                 changyup5@naver.com
# 14062          1.000000                  chanhe87@gmail.com
# 14063          0.888889                  chanen97@gmail.com
# 14064          0.864865                 achan8701@gmail.com
# 14065          1.000000               chanho1128@icloud.com
# 14066          1.000000                chanhonyew@yahoo.com
# 14067          1.000000             chanhsinyee@hotmail.com
# 14068          0.857143                 chailye@hotmail.com
# 14069          0.857143                 ahshine@hotmail.com
# 14070          0.904762               chanhuifang@gmail.com
# 14071          1.000000               chanhuajing@gmail.com
# 14072          0.871795                  chakhang@gmail.com
# 14073          0.864865                    anaing@gmail.com
# 14074          1.000000               chanhuifang@gmail.com
# 14075          0.904762               chanhuajing@gmail.com
# 14076          0.871795                  chakhang@gmail.com
# 14077          1.000000              chanhuiwen96@gmail.com
#
#                                   email_2
# 0                    000grace@hanmail.net
# 1                    00116082@sats.com.sg
# 2                    00248024@sats.com.sg
# 3                     007banggu@naver.com
# 4                       007elee@gmail.com
# 5                       007elee@gmail.com
# 6                00wjddmswn00@hanmail.net
# 7                      0104babi@gmail.com
# 8                      0104babi@gmail.com
# 9                     0106vchng@gmail.com
# 10                     010wlswn@naver.com
# 11                     010wlswn@naver.com
# 12                     0113sota@gmail.com
# 13                   0116149694@naver.com
# 14                  01192876615@naver.com
# 15                   01410ppcom@naver.com
# 16     01533.concierge@starwoodhotels.com
# 17                  01692310506@naver.com
# 18                 0202basket@hanmail.net
# 19                    02qowlsdn@gmail.com
# 20                      0305njd@gmail.com
# 21                   0306isabel@gmail.com
# 22                     0316jina@naver.com
# 23                  0322shunlai@gmail.com
# 24                      0328hsh@naver.com
# 25                    0442hours@gmail.com
# 26                0508tonhyuk@hanmail.net
# 27                     0516hsun@gmail.com
# 28                   06chandarm@aisgz.org
# 29               06chinyichyuan@gmail.com
# ...                                   ...
# 14048             changmanhoong@gmail.com
# 14049             changmanhoong@gmail.com
# 14050                  changq88@gmail.com
# 14051                  changq88@gmail.com
# 14052                  changq88@gmail.com
# 14053                  changq88@gmail.com
# 14054                 changqj89@gmail.com
# 14055                 changqj89@gmail.com
# 14056                 changqj89@gmail.com
# 14057                 changrs95@gmail.com
# 14058               changsheng@live.co.uk
# 14059          changtsejung0411@gmail.com
# 14060       changxi@thegoldenconcepts.com
# 14061                 changyup5@naver.com
# 14062                  chanhe87@gmail.com
# 14063                  chanhe87@gmail.com
# 14064                  chanhe87@gmail.com
# 14065               chanho1128@icloud.com
# 14066                chanhonyew@yahoo.com
# 14067             chanhsinyee@hotmail.com
# 14068             chanhsinyee@hotmail.com
# 14069             chanhsinyee@hotmail.com
# 14070               chanhuajing@gmail.com
# 14071               chanhuajing@gmail.com
# 14072               chanhuajing@gmail.com
# 14073               chanhuajing@gmail.com
# 14074               chanhuifang@gmail.com
# 14075               chanhuifang@gmail.com
# 14076               chanhuifang@gmail.com
# 14077              chanhuiwen96@gmail.com
#
# [14078 rows x 3 columns]
